# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, learning_curve, KFold
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, StandardScaler
import random
from sklearn.svm import SVC
import sklearn.metrics as sk
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import fbeta_score

# %%
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")
validation = pd.read_csv("data/validation.csv")

# %%
columns_tree = pd.read_csv("data/cols_Decission_tree.csv")

# %%
columns_tree = columns_tree["0"].to_list()

# %%
corr_matrix = train.corr().abs()
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]

# %%
to_drop = to_drop + columns_tree

# %%
def clean(df):
    df = df.drop(columns=["Unnamed: 0"])
    df = df.drop(columns=to_drop)
    df = df.rename(columns=lambda x: x.lstrip(" "))
    df = df.rename(columns=lambda x: x.lower())
    df = df.rename(columns=lambda x: x.replace(" ", "_"))
    return df

# %%
train = clean(train)
test = clean(test)
validation = clean(validation)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
train.describe().T
# Out:
#                                                      count          mean  \
# roa(c)_before_interest_and_depreciation_before_...  3426.0  5.064349e-01
# operating_gross_margin                              3426.0  6.081864e-01
# persistent_eps_in_the_last_four_seasons             3426.0  2.292676e-01
# cash_flow_per_share                                 3426.0  3.238340e-01
# realized_sales_gross_profit_growth_rate             3426.0  2.255897e-02
# operating_profit_growth_rate                        3426.0  8.477790e-01
# after-tax_net_profit_growth_rate                    3426.0  6.891099e-01
# total_asset_growth_rate                             3426.0  5.560759e+09
# cash_reinvestment_%                                 3426.0  3.797999e-01
# current_ratio                                       3426.0  1.544379e-02
# quick_ratio                                         3426.0  8.555166e+06
# total_debt/total_net_worth                          3426.0  5.010216e+06
# long-term_fund_suitability_ratio_(a)                3426.0  8.556970e-03
# contingent_liabilities/net_worth                    3426.0  5.827761e-03
# average_collection_days                             3426.0  6.847928e+06
# inventory_turnover_rate_(times)                     3426.0  2.144648e+09
# net_worth_turnover_rate_(times)                     3426.0  3.849895e-02
# operating_profit_per_person                         3426.0  4.009130e-01
# working_capital_to_total_assets                     3426.0  8.141833e-01
# quick_assets/total_assets                           3426.0  3.991711e-01
# current_liability_to_assets                         3426.0  9.029764e-02
# operating_funds_to_liability                        3426.0  3.542229e-01
# current_liabilities/liability                       3426.0  7.626885e-01
# current_liabilities/equity                          3426.0  3.313727e-01
# long-term_liability_to_current_assets               3426.0  4.473759e+07
# retained_earnings_to_total_assets                   3426.0  9.355004e-01
# quick_asset_turnover_rate                           3426.0  2.179268e+09
# fixed_assets_to_assets                              3426.0  2.495659e-01
# equity_to_long-term_liability                       3426.0  1.153823e-01
# cash_flow_to_total_assets                           3426.0  6.494881e-01
# cash_flow_to_liability                              3426.0  4.613705e-01
# cfo_to_assets                                       3426.0  5.946045e-01
# cash_flow_to_equity                                 3426.0  3.156914e-01
# current_liability_to_current_assets                 3426.0  3.129976e-02
# liability-assets_flag                               3426.0  1.167542e-03
# net_income_flag                                     3426.0  1.000000e+00
# equity_to_liability                                 3426.0  4.853559e-02
# bankrupt?                                           3426.0  3.006421e-02
#
#                                                              std       min  \
# roa(c)_before_interest_and_depreciation_before_...  6.126178e-02  0.066933
# operating_gross_margin                              1.838928e-02  0.000000
# persistent_eps_in_the_last_four_seasons             3.113928e-02  0.078567
# cash_flow_per_share                                 1.853920e-02  0.169449
# realized_sales_gross_profit_growth_rate             1.688360e-02  0.009889
# operating_profit_growth_rate                        1.479187e-02  0.000000
# after-tax_net_profit_growth_rate                    1.424621e-02  0.000000
# total_asset_growth_rate                             2.876862e+09  0.000100
# cash_reinvestment_%                                 2.027012e-02  0.000000
# current_ratio                                       2.725959e-02  0.000193
# quick_ratio                                         2.648220e+08  0.000100
# total_debt/total_net_worth                          1.619943e+08  0.000000
# long-term_fund_suitability_ratio_(a)                2.407074e-02  0.000000
# contingent_liabilities/net_worth                    1.975040e-03  0.000000
# average_collection_days                             2.072653e+08  0.000000
# inventory_turnover_rate_(times)                     3.252214e+09  0.000000
# net_worth_turnover_rate_(times)                     3.759209e-02  0.000000
# operating_profit_per_person                         3.507404e-02  0.000000
# working_capital_to_total_assets                     6.034884e-02  0.000000
# quick_assets/total_assets                           2.026489e-01  0.013462
# current_liability_to_assets                         5.113572e-02  0.000000
# operating_funds_to_liability                        3.436262e-02  0.000000
# current_liabilities/liability                       2.052763e-01  0.000000
# current_liabilities/equity                          1.080824e-02  0.241053
# long-term_liability_to_current_assets               4.962319e+08  0.000000
# retained_earnings_to_total_assets                   2.102171e-02  0.592447
# quick_asset_turnover_rate                           3.397476e+09  0.000100
# fixed_assets_to_assets                              2.001234e-01  0.000000
# equity_to_long-term_liability                       1.100083e-02  0.025851
# cash_flow_to_total_assets                           4.761459e-02  0.092089
# cash_flow_to_liability                              3.050132e-02  0.000000
# cfo_to_assets                                       5.814751e-02  0.254224
# cash_flow_to_equity                                 1.513482e-02  0.061964
# current_liability_to_current_assets                 2.632698e-02  0.000000
# liability-assets_flag                               3.415435e-02  0.000000
# net_income_flag                                     0.000000e+00  1.000000
# equity_to_liability                                 5.382829e-02  0.000000
# bankrupt?                                           1.707890e-01  0.000000
#
#                                                              25%  \
# roa(c)_before_interest_and_depreciation_before_...  4.769171e-01
# operating_gross_margin                              6.006284e-01
# persistent_eps_in_the_last_four_seasons             2.149003e-01
# cash_flow_per_share                                 3.178185e-01
# realized_sales_gross_profit_growth_rate             2.206536e-02
# operating_profit_growth_rate                        8.479853e-01
# after-tax_net_profit_growth_rate                    6.892779e-01
# total_asset_growth_rate                             4.990000e+09
# cash_reinvestment_%                                 3.748370e-01
# current_ratio                                       7.579072e-03
# quick_ratio                                         4.706564e-03
# total_debt/total_net_worth                          2.930904e-03
# long-term_fund_suitability_ratio_(a)                5.242912e-03
# contingent_liabilities/net_worth                    5.365848e-03
# average_collection_days                             4.349599e-03
# inventory_turnover_rate_(times)                     1.736854e-04
# net_worth_turnover_rate_(times)                     2.165323e-02
# operating_profit_per_person                         3.925426e-01
# working_capital_to_total_assets                     7.740575e-01
# quick_assets/total_assets                           2.413921e-01
# current_liability_to_assets                         5.289134e-02
# operating_funds_to_liability                        3.410864e-01
# current_liabilities/liability                       6.302264e-01
# current_liabilities/equity                          3.280688e-01
# long-term_liability_to_current_assets               0.000000e+00
# retained_earnings_to_total_assets                   9.314588e-01
# quick_asset_turnover_rate                           1.427109e-04
# fixed_assets_to_assets                              8.439350e-02
# equity_to_long-term_liability                       1.109332e-01
# cash_flow_to_total_assets                           6.333889e-01
# cash_flow_to_liability                              4.570916e-01
# cfo_to_assets                                       5.663648e-01
# cash_flow_to_equity                                 3.130036e-01
# current_liability_to_current_assets                 1.804676e-02
# liability-assets_flag                               0.000000e+00
# net_income_flag                                     1.000000e+00
# equity_to_liability                                 2.469824e-02
# bankrupt?                                           0.000000e+00
#
#                                                              50%  \
# roa(c)_before_interest_and_depreciation_before_...  5.044850e-01
# operating_gross_margin                              6.062353e-01
# persistent_eps_in_the_last_four_seasons             2.252529e-01
# cash_flow_per_share                                 3.226993e-01
# realized_sales_gross_profit_growth_rate             2.210285e-02
# operating_profit_growth_rate                        8.480424e-01
# after-tax_net_profit_growth_rate                    6.894409e-01
# total_asset_growth_rate                             6.430000e+09
# cash_reinvestment_%                                 3.806676e-01
# current_ratio                                       1.058655e-02
# quick_ratio                                         7.443040e-03
# total_debt/total_net_worth                          5.545828e-03
# long-term_fund_suitability_ratio_(a)                5.665693e-03
# contingent_liabilities/net_worth                    5.365848e-03
# average_collection_days                             6.605413e-03
# inventory_turnover_rate_(times)                     7.691645e-04
# net_worth_turnover_rate_(times)                     2.935484e-02
# operating_profit_per_person                         3.960844e-01
# working_capital_to_total_assets                     8.097860e-01
# quick_assets/total_assets                           3.834871e-01
# current_liability_to_assets                         8.216142e-02
# operating_funds_to_liability                        3.487127e-01
# current_liabilities/liability                       8.073007e-01
# current_liabilities/equity                          3.297161e-01
# long-term_liability_to_current_assets               2.063760e-03
# retained_earnings_to_total_assets                   9.380178e-01
# quick_asset_turnover_rate                           2.256352e-04
# fixed_assets_to_assets                              1.968095e-01
# equity_to_long-term_liability                       1.124438e-01
# cash_flow_to_total_assets                           6.452722e-01
# cash_flow_to_liability                              4.597516e-01
# cfo_to_assets                                       5.943316e-01
# cash_flow_to_equity                                 3.149300e-01
# current_liability_to_current_assets                 2.759805e-02
# liability-assets_flag                               0.000000e+00
# net_income_flag                                     1.000000e+00
# equity_to_liability                                 3.378693e-02
# bankrupt?                                           0.000000e+00
#
#                                                              75%           max
# roa(c)_before_interest_and_depreciation_before_...  5.377078e-01  9.715302e-01
# operating_gross_margin                              6.142493e-01  1.000000e+00
# persistent_eps_in_the_last_four_seasons             2.397655e-01  6.621915e-01
# cash_flow_per_share                                 3.289595e-01  1.000000e+00
# realized_sales_gross_profit_growth_rate             2.215335e-02  1.000000e+00
# operating_profit_growth_rate                        8.481219e-01  8.877039e-01
# after-tax_net_profit_growth_rate                    6.896457e-01  8.372050e-01
# total_asset_growth_rate                             7.420000e+09  9.990000e+09
# cash_reinvestment_%                                 3.868312e-01  7.599475e-01
# current_ratio                                       1.625502e-02  1.000000e+00
# quick_ratio                                         1.229090e-02  9.230000e+09
# total_debt/total_net_worth                          9.145852e-03  6.470000e+09
# long-term_fund_suitability_ratio_(a)                6.895597e-03  9.848550e-01
# contingent_liabilities/net_worth                    5.751865e-03  7.316406e-02
# average_collection_days                             8.945124e-03  8.370000e+09
# inventory_turnover_rate_(times)                     4.640000e+09  9.970000e+09
# net_worth_turnover_rate_(times)                     4.290323e-02  1.000000e+00
# operating_profit_per_person                         4.020318e-01  9.781778e-01
# working_capital_to_total_assets                     8.508084e-01  9.891517e-01
# quick_assets/total_assets                           5.417381e-01  9.889440e-01
# current_liability_to_assets                         1.187063e-01  1.000000e+00
# operating_funds_to_liability                        3.620218e-01  7.762974e-01
# current_liabilities/liability                       9.413156e-01  1.000000e+00
# current_liabilities/equity                          3.323053e-01  7.758898e-01
# long-term_liability_to_current_assets               8.978133e-03  9.540000e+09
# retained_earnings_to_total_assets                   9.451505e-01  9.966163e-01
# quick_asset_turnover_rate                           4.895000e+09  1.000000e+10
# fixed_assets_to_assets                              3.757329e-01  1.000000e+00
# equity_to_long-term_liability                       1.170393e-01  4.804404e-01
# cash_flow_to_total_assets                           6.637464e-01  9.704111e-01
# cash_flow_to_liability                              4.643492e-01  8.896518e-01
# cfo_to_assets                                       6.253675e-01  9.751973e-01
# cash_flow_to_equity                                 3.177873e-01  1.000000e+00
# current_liability_to_current_assets                 3.824278e-02  6.117238e-01
# liability-assets_flag                               0.000000e+00  1.000000e+00
# net_income_flag                                     1.000000e+00  1.000000e+00
# equity_to_liability                                 5.414496e-02  1.000000e+00
# bankrupt?                                           0.000000e+00  1.000000e+00

# %%
pd.set_option('display.max_rows', 10)

# %%
train["bankrupt?"].value_counts()
# Out:
# 0    3323
# 1     103
# Name: bankrupt?, dtype: int64

# %%
y_train = train["bankrupt?"]
X_train = train.loc[:, train.columns != 'bankrupt?']
y_test = test["bankrupt?"]
X_test = test.loc[:, test.columns != 'bankrupt?']
y_val = train["bankrupt?"]
X_val = train.loc[:, train.columns != 'bankrupt?']

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(k_neighbors = 3, random_state = 42)

X_train_SMOTE, y_train_SMOTE = sm.fit_resample(X_train, y_train)
y_train_SMOTE.value_counts(normalize = True)
# Out:
# 0    0.5
# 1    0.5
# Name: bankrupt?, dtype: float64

# %%
sc = StandardScaler()

# %%
X_train = sc.fit_transform(X_train)
X_val = sc.transform(X_val)
X_test = sc.transform(X_test)

# %%
X_train_SMOTE = sc.fit_transform(X_train_SMOTE)

# %%
kernel = "linear"
x_data = [X_train, X_train_SMOTE]
y_data = [y_train, y_train_SMOTE]
x_predict = [X_val, X_test]
y_predict = [y_val, y_test]

# %%
def SVM(kernel,X,y,xp,yp):
    lsvclassifier = SVC(kernel=kernel)
    lsvclassifier.fit(X,y)
    accuracies = cross_val_score(estimator = lsvclassifier, X = X, y = y, cv = 5)
    mean_svm_linear=accuracies.mean()
    std_svm_linear=accuracies.std()
    
    print('After 5 fold cross validation:')
    print('Mean of Accuracies: ',mean_svm_linear*100,end='\n')
    print('Standard deviation of Accuracies',std_svm_linear*100,end='\n')
    
    y_pred = lsvclassifier.predict(xp)
    
    print('Test Output:')
    print('Confusion Matrix:')
    print(sk.confusion_matrix(yp,y_pred))
    print('Classification Report:')
    print(sk.classification_report(yp,y_pred))
    print('Accuracy: ',sk.accuracy_score(yp, y_pred, normalize=True, sample_weight=None))
    for i in [0.5, 1, 2]:
        print("beta = ", i ,fbeta_score(yp, y_pred, average = None , beta = i))

# %%
for i in range(len(x_data)):
    for m in range(len(x_predict)):
        SVM(kernel,x_data[i],y_data[i],x_predict[m], y_predict[m])
        print("|||||||||||||||||||||||||")
    print("-------------------")
# Out:
# After 5 fold cross validation:
# Mean of Accuracies:  96.96439743780724
# Standard deviation of Accuracies 0.19354498524236116
# Test Output:
# Confusion Matrix:
# [[3322    1]
#  [  99    4]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99      3323
#            1       0.80      0.04      0.07       103
#
#     accuracy                           0.97      3426
#    macro avg       0.89      0.52      0.53      3426
# weighted avg       0.97      0.97      0.96      3426
#
# Accuracy:  0.9708114419147694
# beta =  0.5 [0.97665667 0.16260163]
# beta =  1 [0.985172   0.07407407]
# beta =  2 [0.99383713 0.04796163]
# |||||||||||||||||||||||||
# After 5 fold cross validation:
# Mean of Accuracies:  96.96439743780724
# Standard deviation of Accuracies 0.19354498524236116
# Test Output:
# Confusion Matrix:
# [[2170    0]
#  [  79    2]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      2170
#            1       1.00      0.02      0.05        81
#
#     accuracy                           0.96      2251
#    macro avg       0.98      0.51      0.52      2251
# weighted avg       0.97      0.96      0.95      2251
#
# Accuracy:  0.9649044868947134
# beta =  0.5 [0.9716998  0.11235955]
# beta =  1 [0.98212265 0.04819277]
# beta =  2 [0.99277153 0.03067485]
# |||||||||||||||||||||||||
# -------------------
# After 5 fold cross validation:
# Mean of Accuracies:  90.7312864554162
# Standard deviation of Accuracies 0.6281623712808887
# Test Output:
# Confusion Matrix:
# [[1717 1606]
#  [   3  100]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.52      0.68      3323
#            1       0.06      0.97      0.11       103
#
#     accuracy                           0.53      3426
#    macro avg       0.53      0.74      0.40      3426
# weighted avg       0.97      0.53      0.66      3426
#
# Accuracy:  0.5303561004086398
# beta =  0.5 [0.84141919 0.07218132]
# beta =  1 [0.68094388 0.11055832]
# beta =  2 [0.57187583 0.23607177]
# |||||||||||||||||||||||||
# After 5 fold cross validation:
# Mean of Accuracies:  90.7312864554162
# Standard deviation of Accuracies 0.6281623712808887
# Test Output:
# Confusion Matrix:
# [[1095 1075]
#  [   2   79]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67      2170
#            1       0.07      0.98      0.13        81
#
#     accuracy                           0.52      2251
#    macro avg       0.53      0.74      0.40      2251
# weighted avg       0.96      0.52      0.65      2251
#
# Accuracy:  0.5215459795646379
# beta =  0.5 [0.83485819 0.08409623]
# beta =  1 [0.67033976 0.12793522]
# beta =  2 [0.55998773 0.26725304]
# |||||||||||||||||||||||||
# -------------------

# %%
from sklearn.utils import compute_class_weight

weights = compute_class_weight('balanced', classes=train['bankrupt?'].unique(), y=train['bankrupt?'])
weights
# Out:
# array([ 0.51549804, 16.63106796])

# %%
#playing around with the pruning to get the best boosting tree
# Applying Grid Search to find the best model and the best parameters
classifiersvc = SVC(random_state=1, class_weight = "balanced")
classifiersvc.fit(X_train_SMOTE, y_train_SMOTE)
from sklearn.model_selection import GridSearchCV

parameters = [{'C': [1,100,300,1000]},
             {'degree': [2,3,4]},
             {'decision_function_shape': ["ovo", "ovr"]}] 
for item in parameters:
    grid_search = GridSearchCV(estimator = classifiersvc,
                               param_grid = item,
                               scoring = 'accuracy',
                               cv = 10,
                               n_jobs = -1)
    grid_search = grid_search.fit(X_train_SMOTE, y_train_SMOTE)
    best_accuracy = grid_search.best_score_
    best_parameters = grid_search.best_params_

    print('Accuracy: ',best_accuracy,end='\n')
    print('Best Parameters: ',best_parameters,end='\n')
# Out:
# Accuracy:  0.9858558293323669
# Best Parameters:  {'C': 1000}
# Accuracy:  0.9470359634024821
# Best Parameters:  {'degree': 2}
# Accuracy:  0.9470359634024821
# Best Parameters:  {'decision_function_shape': 'ovo'}

# %% [markdown]
# # Predictions on test

# %%
classifiersvc = SVC(random_state=1, class_weight = "balanced", C = 1000, degree = 2, decision_function_shape = "ovo")
classifiersvc.fit(X_train_SMOTE,y_train_SMOTE)
y_pred = classifiersvc.predict(X_test)
print(sk.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.83      0.89      2170
#            1       0.09      0.48      0.16        81
#
#     accuracy                           0.81      2251
#    macro avg       0.54      0.65      0.53      2251
# weighted avg       0.95      0.81      0.87      2251

# %%
classifiersvc = SVC(random_state=1, class_weight = "balanced")
classifiersvc.fit(X_train_SMOTE,y_train_SMOTE)
y_pred = classifiersvc.predict(X_test)
print(sk.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.61      0.75      2170
#            1       0.07      0.81      0.13        81
#
#     accuracy                           0.61      2251
#    macro avg       0.53      0.71      0.44      2251
# weighted avg       0.96      0.61      0.73      2251

# %%
for i in [0.5, 1, 2]:
    print("beta = ", i ,fbeta_score(y_test, y_pred, average = None , beta = i))
# Out:
# beta =  0.5 [0.87803576 0.08774262]
# beta =  1 [0.7517852  0.13186813]
# beta =  2 [0.657277   0.26527331]

# %%
print("beta = ", 0.001 ,fbeta_score(y_test, y_pred, average = None , beta = 0.001))
# Out:
# beta =  0.001 [0.98872965 0.0717392 ]

# %%
# TomekLink
from imblearn.under_sampling import TomekLinks

# %%
tl = TomekLinks(sampling_strategy='majority') # play around with sampling_strategy_
X_train_tl, y_train_tl = tl.fit_resample(X_train, y_train)

# %%
print(X_train.shape)
print(X_train_tl.shape) # created synthetic data
# Out:
# (3426, 37)
# (3398, 37)

# %%
y_train_tl.value_counts()
# Out:
# 0    3295
# 1     103
# Name: bankrupt?, dtype: int64

# %%
#playing around with the pruning to get the best boosting tree
# Applying Grid Search to find the best model and the best parameters
from sklearn.ensemble import GradientBoostingClassifier
classifiergb = GradientBoostingClassifier(random_state=1)
classifiergb.fit(X_train, y_train)
from sklearn.model_selection import GridSearchCV

parameters = [{'n_estimators': [50,100,200]},
             {'learning_rate': [0.01,0.1,1]},
             {'subsample': [0.1,0.5,1]}] 
for item in parameters:
    grid_search = GridSearchCV(estimator = classifiergb,
                               param_grid = item,
                               scoring = 'accuracy',
                               cv = 10,
                               n_jobs = -1)
    grid_search = grid_search.fit(X_train, y_train)
    best_accuracy = grid_search.best_score_
    best_parameters = grid_search.best_params_

    print('Accuracy: ',best_accuracy,end='\n')
    print('Best Parameters: ',best_parameters,end='\n')
# Out:
# Accuracy:  0.9664305321125944
# Best Parameters:  {'n_estimators': 50}
# Accuracy:  0.9693528037781528
# Best Parameters:  {'learning_rate': 0.01}
# Accuracy:  0.9649711012224438
# Best Parameters:  {'subsample': 1}

# %%
classifiergb = GradientBoostingClassifier(random_state=1, n_estimators = 50, learning_rate = 0.01, subsample = 1)
classifiergb.fit(X_train_SMOTE, y_train_SMOTE)
y_predgb = classifiergb.predict(X_test)
print(sk.classification_report(y_test, y_predgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.43      0.60      2170
#            1       0.06      0.94      0.11        81
#
#     accuracy                           0.45      2251
#    macro avg       0.53      0.68      0.35      2251
# weighted avg       0.96      0.45      0.58      2251
